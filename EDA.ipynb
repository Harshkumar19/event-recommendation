# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('final_data.csv')

# %%
df.isnull().sum()
# Out:
# event_id         0
# name             0
# group_name       0
# num_members      0
# category_name    0
# weight           0
# year             0
# month            0
# dow              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19307 entries, 0 to 19306
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   event_id       19307 non-null  object
#  1   name           19307 non-null  object
#  2   group_name     19307 non-null  object
#  3   num_members    19307 non-null  int64
#  4   category_name  19307 non-null  object
#  5   weight         19307 non-null  int64
#  6   year           19307 non-null  int64
#  7   month          19307 non-null  int64
#  8   dow            19307 non-null  int64
# dtypes: int64(5), object(4)
# memory usage: 1.3+ MB

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df.corr()
# Out:
#              num_members    weight      year     month       dow
# num_members     1.000000  0.486365  0.080744  0.053626  0.009107
# weight          0.486365  1.000000  0.051170  0.000705  0.038272
# year            0.080744  0.051170  1.000000 -0.293173 -0.008051
# month           0.053626  0.000705 -0.293173  1.000000 -0.008488
# dow             0.009107  0.038272 -0.008051 -0.008488  1.000000

# %%
plt.plot(df.corr())

# %%
df.cov()
# Out:
#               num_members         weight       year       month        dow
# num_members  3.577798e+06  657188.162743  87.041601  320.661871  33.170190
# weight       6.571882e+05  510314.764732  20.832729    1.593118  52.644840
# year         8.704160e+01      20.832729   0.324803   -0.528198  -0.008835
# month        3.206619e+02       1.593118  -0.528198    9.993708  -0.051669
# dow          3.317019e+01      52.644840  -0.008835   -0.051669   3.707832

# %%
sns.countplot(df['group_name'])
# Out:
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='group_name', ylabel='count'>

# %%
df['category_name'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='category_name'>

# %%
import matplotlib.pyplot as plt
plt.hist(df['year'],bins=5)
# Out:
# (array([  747.,     0.,  7176.,     0., 11384.]),
#  array([2015. , 2015.4, 2015.8, 2016.2, 2016.6, 2017. ]),
#  <BarContainer object of 5 artists>)

# %%
sns.distplot(df['year'])
# Out:
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='year', ylabel='Density'>

# %%
sns.distplot(df['month'])
# Out:
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='month', ylabel='Density'>

# %%
sns.boxplot(df['year'])
# Out:
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='year'>

# %%
sns.boxplot(df['month'])
# Out:
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='month'>

# %%
df['num_members'].max()
# Out:
# 15838

# %%
sns.scatterplot(df['num_members'],df['year'])
# Out:
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='num_members', ylabel='year'>

# %%
# sns.barplot(df['group_name'],df['year'])

# %%
# sns.barplot(df['category_name'],df['year'])

# %%
sns.barplot(df['group_name'],df['num_members'])
# Out:
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='group_name', ylabel='num_members'>

# %%
sns.boxplot(df['category_name'],df['year'])
# Out:
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='category_name', ylabel='year'>

# %%
sns.pairplot(df,hue='weight')
# Out:
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
# ...
